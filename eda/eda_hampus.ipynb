# %% [markdown]
# # EDA Hampus Crypto project

# %%
from dotenv import load_dotenv
import os
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
from requests import Session
import json
from pprint import pprint

load_dotenv()

API_KEY = os.getenv("COINMARKET_API")

API_URL = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/quotes/latest"

target_symbol = "CAKE"

parameters = {
    "symbol": target_symbol,
    "convert": "USD",
}

headers = {
    "Accepts": "application/json",
    "X-CMC_PRO_API_KEY": API_KEY,
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(API_URL, params=parameters)
    data = json.loads(response.text)
except(ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)

data
# Out:
# {'status': {'timestamp': '2025-02-16T16:14:03.897Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 34,
#   'credit_count': 1,
#   'notice': None},
#  'data': {'CAKE': {'id': 7186,
#    'name': 'PancakeSwap',
#    'symbol': 'CAKE',
#    'slug': 'pancakeswap',
#    'num_market_pairs': 1632,
#    'date_added': '2020-09-25T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'decentralized-exchange-dex-token',
#     'defi',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'yield-farming',
#     'amm',
#     'binance-smart-chain',
#     'dex',
#     'governance',
#     'bnb-chain-ecosystem',
#     'aptos-ecosystem',
#     'zksync-era-ecosystem',
#     'base-ecosystem',
#     'linea-ecosystem',
#     'polygon-zkevm-ecosystem',
#     'opbnb-ecosystem'],
#    'max_supply': 450000000,
#    'circulating_supply': 297120610.13986313,
#    'total_supply': 384724893.7929145,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x152649eA73beAb28c5b49B26eb48f7EAD6d4c898'},
#    'is_active': 1,
#    'infinite_supply': False,
#    'cmc_rank': 83,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': 0.46954857,
#    'last_updated': '2025-02-16T16:12:00.000Z',
#    'quote': {'USD': {'price': 2.8265005007580064,
#      'volume_24h': 431130810.21905226,
#      'volume_change_24h': 58.9372,
#      'percent_change_1h': 0.60073192,
#      'percent_change_24h': 11.31208437,
#      'percent_change_7d': 56.56485972,
#      'percent_change_30d': 12.27716398,
#      'percent_change_60d': -6.38527587,
#      'percent_change_90d': 44.7182486,
#      'market_cap': 839811553.3458475,
#      'market_cap_dominance': 0.0261,
#      'fully_diluted_market_cap': 1271925225.34,
#      'tvl': 1788550983.3038502,
#      'last_updated': '2025-02-16T16:12:00.000Z'}}}}}

# %%
from dotenv import load_dotenv
import os
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
from requests import Session
import json
from pprint import pprint

load_dotenv()

API_KEY = os.getenv("COINMARKET_API")

API_URL = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest"

target_symbol = "ETH"

parameters = {
    "convert": "USD",
}

headers = {
    "Accepts": "application/json",
    "X-CMC_PRO_API_KEY": API_KEY,
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(API_URL, params=parameters)
    data = json.loads(response.text)
    btc_data = None
    for item in data["data"]:
        if item["symbol"] == target_symbol:
            btc_data = item
            break  # Stoppa loopen när vi hittar BTC
    print(json.dumps(btc_data, indent=4))
except(ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)

data
# Out:
# {
#     "id": 1027,
#     "name": "Ethereum",
#     "symbol": "ETH",
#     "slug": "ethereum",
#     "num_market_pairs": 9931,
#     "date_added": "2015-08-07T00:00:00.000Z",
#     "tags": [
#         "pos",
#         "smart-contracts",
#         "ethereum-ecosystem",
#         "coinbase-ventures-portfolio",
#         "three-arrows-capital-portfolio",
#         "polychain-capital-portfolio",
#         "heco-ecosystem",
#         "binance-labs-portfolio",
#         "solana-ecosystem",
#         "blockchain-capital-portfolio",
#         "boostvc-portfolio",
#         "cms-holdings-portfolio",
#         "dcg-portfolio",
#         "dragonfly-capital-portfolio",
#         "electric-capital-portfolio",
#         "fabric-ventures-portfolio",
#         "framework-ventures-portfolio",
#         "hashkey-capital-portfolio",
#         "kenetic-capital-portfolio",
#         "huobi-capital-portfolio",
#         "alameda-research-portfolio",
#         "a16z-portfolio",
#         "1confirmation-portfolio",
#         "winklevoss-capital-portfolio",
#         "usv-portfolio",
#         "placeholder-ventures-portfolio",
#         "pantera-capital-portfolio",
#         "multicoin-capital-portfolio",
#         "paradigm-portfolio",
#         "tezos-ecosystem",
#         "near-protocol-ecosystem",
#         "velas-ecosystem",
#         "ethereum-pow-ecosystem",
#         "osmosis-ecosystem",
#         "layer-1",
#         "ftx-bankruptcy-estate",
#         "zksync-era-ecosystem",
#         "viction-ecosystem",
#         "klaytn-ecosystem",
#         "sora-ecosystem",
#         "rsk-rbtc-ecosystem",
#         "starknet-ecosystem"
#     ],
#     "max_supply": null,
#     "circulating_supply": 120547760.01376195,
#     "total_supply": 120547760.01376195,
#     "infinite_supply": true,
#     "platform": null,
#     "cmc_rank": 2,
#     "self_reported_circulating_supply": null,
#     "self_reported_market_cap": null,
#     "tvl_ratio": null,
#     "last_updated": "2025-02-14T15:13:00.000Z",
#     "quote": {
#         "USD": {
#             "price": 2708.1378060714583,
#             "volume_24h": 14332337374.136421,
#             "volume_change_24h": -39.4455,
#             "percent_change_1h": 0.21209791,
#             "percent_change_24h": 2.83716969,
#             "percent_change_7d": -1.05179995,
#             "percent_change_30d": -18.90113654,
#             "percent_change_60d": -31.22725909,
#             "percent_change_90d": -13.87692382,
#             "market_cap": 326459946330.498,
#             "market_cap_dominance": 10.0931,
#             "fully_diluted_market_cap": 326459946330.5,
#             "tvl": null,
#             "last_updated": "2025-02-14T15:13:00.000Z"
#         }
#     }
# }
# {'status': {'timestamp': '2025-02-14T15:15:25.281Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 18,
#   'credit_count': 1,
#   'notice': None,
#   'total_count': 10883},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 11941,
#    'date_added': '2010-07-13T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'galaxy-digital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'bitcoin-ecosystem',
#     'ftx-bankruptcy-estate',
#     '2017-2018-alt-season'],
#    'max_supply': 21000000,
#    'circulating_supply': 19824178,
#    'total_supply': 19824178,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 1,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 96778.08931351,
#      'volume_24h': 27884497335.710316,
#      'volume_change_24h': -37.3684,
#      'percent_change_1h': -0.01766774,
#      'percent_change_24h': 1.16432082,
#      'percent_change_7d': -1.68183749,
#      'percent_change_30d': -2.76595149,
#      'percent_change_60d': -8.79975965,
#      'percent_change_90d': 6.82778662,
#      'market_cap': 1918546069050.9202,
#      'market_cap_dominance': 59.3155,
#      'fully_diluted_market_cap': 2032339875583.71,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 9931,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'tags': ['pos',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'heco-ecosystem',
#     'binance-labs-portfolio',
#     'solana-ecosystem',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'tezos-ecosystem',
#     'near-protocol-ecosystem',
#     'velas-ecosystem',
#     'ethereum-pow-ecosystem',
#     'osmosis-ecosystem',
#     'layer-1',
#     'ftx-bankruptcy-estate',
#     'zksync-era-ecosystem',
#     'viction-ecosystem',
#     'klaytn-ecosystem',
#     'sora-ecosystem',
#     'rsk-rbtc-ecosystem',
#     'starknet-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 120547760.01376195,
#    'total_supply': 120547760.01376195,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 2,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 2708.1378060714583,
#      'volume_24h': 14332337374.136421,
#      'volume_change_24h': -39.4455,
#      'percent_change_1h': 0.21209791,
#      'percent_change_24h': 2.83716969,
#      'percent_change_7d': -1.05179995,
#      'percent_change_30d': -18.90113654,
#      'percent_change_60d': -31.22725909,
#      'percent_change_90d': -13.87692382,
#      'market_cap': 326459946330.498,
#      'market_cap_dominance': 10.0931,
#      'fully_diluted_market_cap': 326459946330.5,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'num_market_pairs': 1529,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'xrp-ecosystem',
#     'arrington-xrp-capital-portfolio',
#     'galaxy-digital-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'ftx-bankruptcy-estate',
#     '2017-2018-alt-season',
#     'klaytn-ecosystem',
#     'made-in-america'],
#    'max_supply': 100000000000,
#    'circulating_supply': 57818864895,
#    'total_supply': 99986451428,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 3,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 2.7208969460030965,
#      'volume_24h': 8425817174.973305,
#      'volume_change_24h': 99.7503,
#      'percent_change_1h': -0.33629807,
#      'percent_change_24h': 12.08221501,
#      'percent_change_7d': 9.27858829,
#      'percent_change_30d': -6.55319154,
#      'percent_change_60d': 14.39387285,
#      'percent_change_90d': 134.25603523,
#      'market_cap': 157319172914.17114,
#      'market_cap_dominance': 4.8682,
#      'fully_diluted_market_cap': 272089694600.31,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 825,
#    'name': 'Tether USDt',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'num_market_pairs': 116771,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'ethereum-ecosystem',
#     'waves-ecosystem',
#     'bitcoin-cash-ecosystem',
#     'heco-ecosystem',
#     'algorand-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'tezos-ecosystem',
#     'near-protocol-ecosystem',
#     'arbitrum-ecosystem',
#     'celo-ecosystem',
#     'iotex-ecosystem',
#     'zilliqa-ecosystem',
#     'harmony-ecosystem',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'oasis-ecosystem',
#     'moonbeam-ecosystem',
#     'usd-stablecoin',
#     'xdc-ecosystem',
#     'everscale-ecosystem',
#     'velas-ecosystem',
#     'ethereum-pow-ecosystem',
#     'aptos-ecosystem',
#     'sui-ecosystem',
#     'optimism-ecosystem',
#     'canto-ecosystem',
#     'osmosis-ecosystem',
#     'zksync-era-ecosystem',
#     'pulsechain-ecosystem',
#     'sei-ecosystem',
#     'toncoin-ecosystem',
#     'fiat-stablecoin',
#     'viction-ecosystem',
#     'gnosis-chain-ecosystem',
#     'klaytn-ecosystem',
#     'okexchain-ecosystem',
#     'conflux-ecosystem',
#     'kcc-ecosystem',
#     'tron20-ecosystem',
#     'kardiachain-ecosystem',
#     'rsk-rbtc-ecosystem',
#     'telos-ecosystem',
#     'boba-network-ecosystem',
#     'fusion-network-ecosystem',
#     'hoo-smart-chain-ecosystem',
#     'secret-ecosystem',
#     'aurora-ecosystem',
#     'metis-andromeda-ecosystem',
#     'meter-ecosystem',
#     'fuse-ecosystem',
#     'syscoin-ecosystem',
#     'milkomeda-ecosystem',
#     'bitgert-ecosystem',
#     'astar-ecosystem',
#     'cube-network-ecosystem',
#     'thundercore-ecosystem',
#     'redlight-chain-ecosystem',
#     'core-ecosystem',
#     'polygon-zkevm-ecosystem',
#     'eos-evm-ecosystem',
#     'starknet-ecosystem',
#     'mantle-ecosystem',
#     'neon-evm-ecosystem',
#     'manta-pacific-ecosystem',
#     'scroll-ecosystem',
#     'x-layer-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 141805189026.5491,
#    'total_supply': 143566824834.1635,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#    'infinite_supply': True,
#    'cmc_rank': 4,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 1.0001838757506165,
#      'volume_24h': 72341848224.40414,
#      'volume_change_24h': -25.254,
#      'percent_change_1h': 0.00212528,
#      'percent_change_24h': 0.02305019,
#      'percent_change_7d': -0.03317925,
#      'percent_change_30d': 0.01532855,
#      'percent_change_60d': 0.03879225,
#      'percent_change_90d': 0.01028258,
#      'market_cap': 141831263562.12268,
#      'market_cap_dominance': 4.385,
#      'fully_diluted_market_cap': 143593223291.84,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 5426,
#    'name': 'Solana',
#    'symbol': 'SOL',
#    'slug': 'solana',
#    'num_market_pairs': 840,
#    'date_added': '2020-04-10T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'okx-ventures-portfolio',
#     'layer-1',
#     'ftx-bankruptcy-estate',
#     'alleged-sec-securities',
#     'cmc-crypto-awards-2024',
#     'made-in-america'],
#    'max_supply': None,
#    'circulating_supply': 488289013.59169185,
#    'total_supply': 594077401.9825375,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 5,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 200.40065899724166,
#      'volume_24h': 2859328677.652098,
#      'volume_change_24h': -19.6149,
#      'percent_change_1h': 1.14516549,
#      'percent_change_24h': 5.38980869,
#      'percent_change_7d': 0.40945562,
#      'percent_change_30d': 1.89949306,
#      'percent_change_60d': -7.54649396,
#      'percent_change_90d': -6.78379438,
#      'market_cap': 97853440104.88814,
#      'market_cap_dominance': 3.0269,
#      'fully_diluted_market_cap': 119053502852.67,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 1839,
#    'name': 'BNB',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'num_market_pairs': 2360,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'payments',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'bnb-chain-ecosystem',
#     'layer-1',
#     'alleged-sec-securities',
#     'celsius-bankruptcy-estate'],
#    'max_supply': None,
#    'circulating_supply': 142477999.11,
#    'total_supply': 142477999.11,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 6,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:14:00.000Z',
#    'quote': {'USD': {'price': 664.5816862894678,
#      'volume_24h': 3688843099.3618593,
#      'volume_change_24h': -21.4387,
#      'percent_change_1h': -0.0774097,
#      'percent_change_24h': -5.52397701,
#      'percent_change_7d': 13.74665398,
#      'percent_change_30d': -5.6591702,
#      'percent_change_60d': -6.9248536,
#      'percent_change_90d': 6.09648572,
#      'market_cap': 94688268907.67311,
#      'market_cap_dominance': 2.9279,
#      'fully_diluted_market_cap': 94688268907.67,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:14:00.000Z'}}},
#   {'id': 3408,
#    'name': 'USDC',
#    'symbol': 'USDC',
#    'slug': 'usd-coin',
#    'num_market_pairs': 25688,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'ethereum-ecosystem',
#     'waves-ecosystem',
#     'bitcoin-cash-ecosystem',
#     'wanchain-ecosystem',
#     'coinbase-ventures-portfolio',
#     'algorand-ecosystem',
#     'solana-ecosystem',
#     'hedera-hashgraph-ecosystem',
#     'polygon-ecosystem',
#     'near-protocol-ecosystem',
#     'arbitrum-ecosystem',
#     'celo-ecosystem',
#     'iotex-ecosystem',
#     'harmony-ecosystem',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'oasis-ecosystem',
#     'moonbeam-ecosystem',
#     'usd-stablecoin',
#     'everscale-ecosystem',
#     'velas-ecosystem',
#     'ethereum-pow-ecosystem',
#     'aptos-ecosystem',
#     'sui-ecosystem',
#     'optimism-ecosystem',
#     'canto-ecosystem',
#     'osmosis-ecosystem',
#     'zksync-era-ecosystem',
#     'pulsechain-ecosystem',
#     'base-ecosystem',
#     'sei-ecosystem',
#     'multiversx-ecosystem',
#     'fiat-stablecoin',
#     'viction-ecosystem',
#     'gnosis-chain-ecosystem',
#     'okexchain-ecosystem',
#     'conflux-ecosystem',
#     'kcc-ecosystem',
#     'tron20-ecosystem',
#     'kardiachain-ecosystem',
#     'telos-ecosystem',
#     'ronin-ecosystem',
#     'boba-network-ecosystem',
#     'kava-ecosystem',
#     'secret-ecosystem',
#     'aurora-ecosystem',
#     'metis-andromeda-ecosystem',
#     'meter-ecosystem',
#     'fuse-ecosystem',
#     'elastos-ecosystem',
#     'syscoin-ecosystem',
#     'milkomeda-ecosystem',
#     'evmos-ecosystem',
#     'bitgert-ecosystem',
#     'astar-ecosystem',
#     'thundercore-ecosystem',
#     'tomb-chain-ecosystem',
#     'wemix-ecosystem',
#     'sx-network-ecosystem',
#     'godwoken-ecosystem',
#     'energi-ecosystem',
#     'core-ecosystem',
#     'polygon-zkevm-ecosystem',
#     'starknet-ecosystem',
#     'mantle-ecosystem',
#     'neon-evm-ecosystem',
#     'scroll-ecosystem',
#     'shido-network-ecosystem',
#     'made-in-america'],
#    'max_supply': None,
#    'circulating_supply': 56163920161.99188,
#    'total_supply': 56163920161.99188,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'infinite_supply': False,
#    'cmc_rank': 7,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.9999952186528767,
#      'volume_24h': 6904262707.473859,
#      'volume_change_24h': -21.2828,
#      'percent_change_1h': -0.00431522,
#      'percent_change_24h': 0.00296816,
#      'percent_change_7d': 0.00858025,
#      'percent_change_30d': -0.01603881,
#      'percent_change_60d': 0.0021497,
#      'percent_change_90d': 0.02980679,
#      'market_cap': 56163651622.79378,
#      'market_cap_dominance': 1.7364,
#      'fully_diluted_market_cap': 56163651622.79,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'num_market_pairs': 1163,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'memes',
#     'payments',
#     'doggone-doggerel',
#     'ftx-bankruptcy-estate',
#     'made-in-america'],
#    'max_supply': None,
#    'circulating_supply': 148043566383.70526,
#    'total_supply': 148043566383.70526,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 8,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.27209166084787734,
#      'volume_24h': 1843826574.3463058,
#      'volume_change_24h': 6.5554,
#      'percent_change_1h': 0.35994287,
#      'percent_change_24h': 6.81162487,
#      'percent_change_7d': 6.18646694,
#      'percent_change_30d': -26.15789902,
#      'percent_change_60d': -31.73304398,
#      'percent_change_90d': -25.28207709,
#      'market_cap': 40281419855.18535,
#      'market_cap_dominance': 1.2454,
#      'fully_diluted_market_cap': 40281419855.19,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 2010,
#    'name': 'Cardano',
#    'symbol': 'ADA',
#    'slug': 'cardano',
#    'num_market_pairs': 1460,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'tags': ['dpos',
#     'pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'staking',
#     'cardano-ecosystem',
#     'cardano',
#     'layer-1',
#     'alleged-sec-securities',
#     '2017-2018-alt-season',
#     'made-in-america'],
#    'max_supply': 45000000000,
#    'circulating_supply': 35201193525.86875,
#    'total_supply': 44994975100.72033,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 9,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.8092678633477441,
#      'volume_24h': 835097986.5154333,
#      'volume_change_24h': 1.7022,
#      'percent_change_1h': 0.12540909,
#      'percent_change_24h': 4.03596755,
#      'percent_change_7d': 9.9270778,
#      'percent_change_30d': -23.35499224,
#      'percent_change_60d': -24.08352798,
#      'percent_change_90d': 1.56958201,
#      'market_cap': 28487194671.97025,
#      'market_cap_dominance': 0.8807,
#      'fully_diluted_market_cap': 36417053850.65,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'num_market_pairs': 1118,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'tags': ['media',
#     'payments',
#     'ethereum-ecosystem',
#     'tron-ecosystem',
#     'layer-1',
#     'dwf-labs-portfolio',
#     'alleged-sec-securities',
#     '2017-2018-alt-season',
#     'tron20-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 86097121081.48189,
#    'total_supply': 86097177573.25656,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 10,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.23151939493216578,
#      'volume_24h': 471773881.1475196,
#      'volume_change_24h': -22.1517,
#      'percent_change_1h': 0.10367515,
#      'percent_change_24h': -1.63483155,
#      'percent_change_7d': 0.29878674,
#      'percent_change_30d': 0.39411982,
#      'percent_change_60d': -17.31841793,
#      'percent_change_90d': 15.15538887,
#      'market_cap': 19933153378.1861,
#      'market_cap_dominance': 0.6163,
#      'fully_diluted_market_cap': 19933166457.13,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 1927,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'substrate',
#     'polkadot',
#     'heco-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'cardano-ecosystem',
#     'web3',
#     'near-protocol-ecosystem',
#     'arbitrum-ecosystem',
#     'cardano',
#     'injective-ecosystem',
#     'optimism-ecosystem',
#     'real-world-assets',
#     'celsius-bankruptcy-estate',
#     'gnosis-chain-ecosystem',
#     'sora-ecosystem',
#     'hoo-smart-chain-ecosystem',
#     'milkomeda-ecosystem',
#     'energi-ecosystem',
#     'made-in-america'],
#    'max_supply': None,
#    'circulating_supply': 638099970.4527867,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'infinite_supply': False,
#    'cmc_rank': 11,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 19.38989681071637,
#      'volume_24h': 372614994.6710373,
#      'volume_change_24h': -23.1176,
#      'percent_change_1h': 0.59254715,
#      'percent_change_24h': 6.27437232,
#      'percent_change_7d': -0.04324553,
#      'percent_change_30d': -10.04596737,
#      'percent_change_60d': -35.65007395,
#      'percent_change_90d': 36.47232797,
#      'market_cap': 12372692582.000698,
#      'market_cap_dominance': 0.3825,
#      'fully_diluted_market_cap': 19389896810.72,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 20947,
#    'name': 'Sui',
#    'symbol': 'SUI',
#    'slug': 'sui',
#    'num_market_pairs': 554,
#    'date_added': '2022-07-12T08:03:11.000Z',
#    'tags': ['binance-launchpool',
#     'coinbase-ventures-portfolio',
#     'binance-labs-portfolio',
#     'electric-capital-portfolio',
#     'a16z-portfolio',
#     'sui-ecosystem',
#     'layer-1',
#     'move-vm',
#     'cmc-crypto-yearbook-2024-2025',
#     'made-in-america'],
#    'max_supply': 10000000000,
#    'circulating_supply': 3089707194.508888,
#    'total_supply': 10000000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 12,
#    'self_reported_circulating_supply': 3089707194.508888,
#    'self_reported_market_cap': 11264221804.485983,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 3.6457246901923477,
#      'volume_24h': 949605607.0663325,
#      'volume_change_24h': -37.7992,
#      'percent_change_1h': 0.96750418,
#      'percent_change_24h': 6.11578342,
#      'percent_change_7d': 11.21575652,
#      'percent_change_30d': -24.36999487,
#      'percent_change_60d': -23.25504966,
#      'percent_change_90d': -0.85067225,
#      'market_cap': 11264221804.485983,
#      'market_cap_dominance': 0.3483,
#      'fully_diluted_market_cap': 36457246901.92,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 5805,
#    'name': 'Avalanche',
#    'symbol': 'AVAX',
#    'slug': 'avalanche',
#    'num_market_pairs': 861,
#    'date_added': '2020-07-13T00:00:00.000Z',
#    'tags': ['defi',
#     'smart-contracts',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'avalanche-ecosystem',
#     'cms-holdings-portfolio',
#     'dragonfly-capital-portfolio',
#     'moonbeam-ecosystem',
#     'real-world-assets',
#     'layer-1',
#     'zksync-era-ecosystem',
#     'klaytn-ecosystem',
#     'made-in-america'],
#    'max_supply': 715748719,
#    'circulating_supply': 411959965.75782377,
#    'total_supply': 450296265.75782377,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 13,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 26.437532872009065,
#      'volume_24h': 271568384.48228353,
#      'volume_change_24h': -28.7767,
#      'percent_change_1h': 0.92100455,
#      'percent_change_24h': 4.22479112,
#      'percent_change_7d': 2.99720026,
#      'percent_change_30d': -32.92180078,
#      'percent_change_60d': -46.18122198,
#      'percent_change_90d': -24.61640599,
#      'market_cap': 10891205136.674194,
#      'market_cap_dominance': 0.3367,
#      'fully_diluted_market_cap': 18922630286.66,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'num_market_pairs': 674,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'decentralized-exchange-dex-token',
#     'smart-contracts',
#     'hashkey-capital-portfolio',
#     '2017-2018-alt-season',
#     'made-in-america'],
#    'max_supply': 50001806812,
#    'circulating_supply': 30603012216.49101,
#    'total_supply': 50001786894.450165,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 14,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.3506526444063791,
#      'volume_24h': 419862464.07434076,
#      'volume_change_24h': 58.2561,
#      'percent_change_1h': -0.3866308,
#      'percent_change_24h': 8.01535621,
#      'percent_change_7d': 3.31435556,
#      'percent_change_30d': -26.95424637,
#      'percent_change_60d': -14.91042144,
#      'percent_change_90d': 87.00722191,
#      'market_cap': 10731027160.513298,
#      'market_cap_dominance': 0.3321,
#      'fully_diluted_market_cap': 17533265783.72,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 5994,
#    'name': 'Shiba Inu',
#    'symbol': 'SHIB',
#    'slug': 'shiba-inu',
#    'num_market_pairs': 932,
#    'date_added': '2020-08-01T00:00:00.000Z',
#    'tags': ['memes',
#     'ethereum-ecosystem',
#     'doggone-doggerel',
#     'base-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 589253883189884.1,
#    'total_supply': 589507245267452.1,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#    'infinite_supply': False,
#    'cmc_rank': 15,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 1.6690161734157413e-05,
#      'volume_24h': 275426388.1619929,
#      'volume_change_24h': -30.1921,
#      'percent_change_1h': 0.00835886,
#      'percent_change_24h': 3.81281422,
#      'percent_change_7d': 8.1785482,
#      'percent_change_30d': -24.63561663,
#      'percent_change_60d': -38.14534339,
#      'percent_change_90d': -31.5291059,
#      'market_cap': 9834742612.919466,
#      'market_cap_dominance': 0.3041,
#      'fully_diluted_market_cap': 9838971266.97,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'num_market_pairs': 1315,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'heco-ecosystem',
#     'layer-1',
#     '2017-2018-alt-season',
#     'hoo-smart-chain-ecosystem',
#     'made-in-america'],
#    'max_supply': 84000000,
#    'circulating_supply': 75531880.8040892,
#    'total_supply': 84000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 16,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 128.54039163294755,
#      'volume_24h': 1647388960.1235669,
#      'volume_change_24h': 15.1006,
#      'percent_change_1h': -0.46999573,
#      'percent_change_24h': 7.16721005,
#      'percent_change_7d': 21.17651244,
#      'percent_change_30d': 22.0902501,
#      'percent_change_60d': 9.74524188,
#      'percent_change_90d': 39.20763311,
#      'market_cap': 9708897539.33074,
#      'market_cap_dominance': 0.3002,
#      'fully_diluted_market_cap': 10797392897.17,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 11419,
#    'name': 'Toncoin',
#    'symbol': 'TON',
#    'slug': 'toncoin',
#    'num_market_pairs': 673,
#    'date_added': '2021-08-26T13:40:22.000Z',
#    'tags': ['pos',
#     'ethereum-ecosystem',
#     'layer-1',
#     'ftx-bankruptcy-estate',
#     'dwf-labs-portfolio',
#     'toncoin-ecosystem',
#     'cmc-crypto-yearbook-2024-2025'],
#    'max_supply': None,
#    'circulating_supply': 2494253634.4647923,
#    'total_supply': 5122293244.857368,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 17,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 3.823509528862005,
#      'volume_24h': 133643363.20447358,
#      'volume_change_24h': -14.5694,
#      'percent_change_1h': -0.01088286,
#      'percent_change_24h': 4.16074633,
#      'percent_change_7d': 0.09716592,
#      'percent_change_30d': -29.49772896,
#      'percent_change_60d': -36.26362854,
#      'percent_change_90d': -32.44279002,
#      'market_cap': 9536802538.77482,
#      'market_cap_dominance': 0.2948,
#      'fully_diluted_market_cap': 19585137031.34,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 32196,
#    'name': 'Hyperliquid',
#    'symbol': 'HYPE',
#    'slug': 'hyperliquid',
#    'num_market_pairs': 51,
#    'date_added': '2024-07-15T10:14:50.000Z',
#    'tags': ['decentralized-exchange-dex-token',
#     'derivatives',
#     'layer-1',
#     'hyperliquid-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 333928180,
#    'total_supply': 999993930,
#    'platform': {'id': 32196,
#     'name': 'Hyperliquid',
#     'symbol': 'HYPE',
#     'slug': 'hyperliquid',
#     'token_address': '0x0d01dc56dcaaca66ad901c959b4011ec'},
#    'infinite_supply': False,
#    'cmc_rank': 18,
#    'self_reported_circulating_supply': 333931719,
#    'self_reported_market_cap': 9168799419.571884,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 27.45710843830287,
#      'volume_24h': 145126778.5705032,
#      'volume_change_24h': -16.8135,
#      'percent_change_1h': -0.56517108,
#      'percent_change_24h': 9.77285885,
#      'percent_change_7d': 13.15405961,
#      'percent_change_30d': 15.38101921,
#      'percent_change_60d': 2.60886191,
#      'percent_change_90d': 757.96051276,
#      'market_cap': 9168702248.86512,
#      'market_cap_dominance': 0.2835,
#      'fully_diluted_market_cap': 27457108438.3,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 3957,
#    'name': 'UNUS SED LEO',
#    'symbol': 'LEO',
#    'slug': 'unus-sed-leo',
#    'num_market_pairs': 57,
#    'date_added': '2019-05-21T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'discount-token',
#     'payments',
#     'ethereum-ecosystem',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 924129449.9,
#    'total_supply': 985239504,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#    'infinite_supply': False,
#    'cmc_rank': 19,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:14:00.000Z',
#    'quote': {'USD': {'price': 9.823635030919599,
#      'volume_24h': 677293.09565394,
#      'volume_change_24h': -21.7504,
#      'percent_change_1h': 0.18999875,
#      'percent_change_24h': 0.50542706,
#      'percent_change_7d': -0.02817298,
#      'percent_change_30d': 2.47513152,
#      'percent_change_60d': 2.49898554,
#      'percent_change_90d': 28.17906502,
#      'market_cap': 9078310437.142097,
#      'market_cap_dominance': 0.2807,
#      'fully_diluted_market_cap': 9678633305.34,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:14:00.000Z'}}},
#   {'id': 4642,
#    'name': 'Hedera',
#    'symbol': 'HBAR',
#    'slug': 'hedera',
#    'num_market_pairs': 316,
#    'date_added': '2019-09-17T00:00:00.000Z',
#    'tags': ['dag',
#     'marketplace',
#     'enterprise-solutions',
#     'defi',
#     'payments',
#     'dcg-portfolio',
#     'hedera-hashgraph-ecosystem',
#     'real-world-assets',
#     'layer-1',
#     'made-in-america'],
#    'max_supply': 50000000000,
#    'circulating_supply': 38269622458.15292,
#    'total_supply': 50000000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 20,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.23510375633149685,
#      'volume_24h': 283936896.5416721,
#      'volume_change_24h': -8.8945,
#      'percent_change_1h': 0.09147078,
#      'percent_change_24h': 6.05103759,
#      'percent_change_7d': -2.7559591,
#      'percent_change_30d': -25.59604706,
#      'percent_change_60d': -16.10674034,
#      'percent_change_90d': 163.88275761,
#      'market_cap': 8997331993.299965,
#      'market_cap_dominance': 0.2782,
#      'fully_diluted_market_cap': 11755187816.57,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 6636,
#    'name': 'Polkadot',
#    'symbol': 'DOT',
#    'slug': 'polkadot-new',
#    'num_market_pairs': 865,
#    'date_added': '2020-08-19T00:00:00.000Z',
#    'tags': ['substrate',
#     'polkadot',
#     'polkadot-ecosystem',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'heco-ecosystem',
#     'arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'coinfund-portfolio',
#     'fabric-ventures-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'web3',
#     'spartan-group',
#     'osmosis-ecosystem',
#     'layer-1',
#     'made-in-america'],
#    'max_supply': None,
#    'circulating_supply': 1548578939.6437573,
#    'total_supply': 1548578939.6437573,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 21,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 5.212338060060784,
#      'volume_24h': 192312786.6664033,
#      'volume_change_24h': -47.3958,
#      'percent_change_1h': -0.61841829,
#      'percent_change_24h': 1.78537977,
#      'percent_change_7d': 7.46087202,
#      'percent_change_30d': -25.13651698,
#      'percent_change_60d': -40.69886323,
#      'percent_change_90d': -5.13565828,
#      'market_cap': 8071716946.113728,
#      'market_cap_dominance': 0.2496,
#      'fully_diluted_market_cap': 8071716946.11,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 1831,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'slug': 'bitcoin-cash',
#    'num_market_pairs': 977,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'marketplace',
#     'medium-of-exchange',
#     'store-of-value',
#     'enterprise-solutions',
#     'payments',
#     'heco-ecosystem',
#     'bitcoin-ecosystem',
#     'layer-1',
#     '2017-2018-alt-season',
#     'made-in-america'],
#    'max_supply': 21000000,
#    'circulating_supply': 19829356.25,
#    'total_supply': 19829356.25,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 22,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 344.24743383738627,
#      'volume_24h': 244194198.1329001,
#      'volume_change_24h': -9.3841,
#      'percent_change_1h': 0.21882682,
#      'percent_change_24h': 4.5836519,
#      'percent_change_7d': 4.22623625,
#      'percent_change_30d': -23.06509461,
#      'percent_change_60d': -35.41776039,
#      'percent_change_90d': -25.60717355,
#      'market_cap': 6826205003.709837,
#      'market_cap_dominance': 0.2112,
#      'fully_diluted_market_cap': 7229196110.59,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 11092,
#    'name': 'Bitget Token',
#    'symbol': 'BGB',
#    'slug': 'bitget-token-new',
#    'num_market_pairs': 30,
#    'date_added': '2021-07-29T00:00:00.000Z',
#    'tags': ['centralized-exchange', 'ethereum-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 1200000000,
#    'total_supply': 1200000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x54D2252757e1672EEaD234D27B1270728fF90581'},
#    'infinite_supply': False,
#    'cmc_rank': 23,
#    'self_reported_circulating_supply': 1200000000,
#    'self_reported_market_cap': 6689160315.439246,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 5.574300262866038,
#      'volume_24h': 301653411.4530946,
#      'volume_change_24h': -28.0246,
#      'percent_change_1h': 0.52883759,
#      'percent_change_24h': 2.34821948,
#      'percent_change_7d': -16.84277796,
#      'percent_change_30d': -14.24484862,
#      'percent_change_60d': 63.57039621,
#      'percent_change_90d': 301.64207169,
#      'market_cap': 6689160315.439246,
#      'market_cap_dominance': 0.2068,
#      'fully_diluted_market_cap': 6689160315.44,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 7083,
#    'name': 'Uniswap',
#    'symbol': 'UNI',
#    'slug': 'uniswap',
#    'num_market_pairs': 1166,
#    'date_added': '2020-09-17T00:00:00.000Z',
#    'tags': ['decentralized-exchange-dex-token',
#     'defi',
#     'dao',
#     'ethereum-ecosystem',
#     'yield-farming',
#     'amm',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'heco-ecosystem',
#     'solana-ecosystem',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-portfolio',
#     'polygon-ecosystem',
#     'near-protocol-ecosystem',
#     'arbitrum-ecosystem',
#     'injective-ecosystem',
#     'optimism-ecosystem',
#     'layer-1',
#     'cmc-crypto-awards-2024',
#     'gnosis-chain-ecosystem',
#     'sora-ecosystem',
#     'hoo-smart-chain-ecosystem',
#     'made-in-america'],
#    'max_supply': None,
#    'circulating_supply': 600518037.71,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'infinite_supply': False,
#    'cmc_rank': 24,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 10.037609977435775,
#      'volume_24h': 178809283.62681302,
#      'volume_change_24h': -16.2085,
#      'percent_change_1h': -0.26397148,
#      'percent_change_24h': 5.61554487,
#      'percent_change_7d': 8.38399176,
#      'percent_change_30d': -29.11019231,
#      'percent_change_60d': -38.98129443,
#      'percent_change_90d': 12.60629853,
#      'market_cap': 6027765846.94805,
#      'market_cap_dominance': 0.1864,
#      'fully_diluted_market_cap': 10037609977.44,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 29470,
#    'name': 'Ethena USDe',
#    'symbol': 'USDe',
#    'slug': 'ethena-usde',
#    'num_market_pairs': 105,
#    'date_added': '2024-02-20T11:05:01.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'ethereum-ecosystem',
#     'binance-labs-portfolio',
#     'dragonfly-capital-portfolio',
#     'usd-stablecoin',
#     'optimism-ecosystem',
#     'linea-ecosystem',
#     'eigenlayer-ecosystem',
#     'kava-ecosystem',
#     'metis-andromeda-ecosystem',
#     'mantle-ecosystem',
#     'manta-pacific-ecosystem',
#     'scroll-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 5987231037.220328,
#    'total_supply': 5987231037.220328,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4c9edd5852cd905f086c759e8383e09bff1e68b3'},
#    'infinite_supply': True,
#    'cmc_rank': 25,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 1.0000752878253312,
#      'volume_24h': 110921667.02176726,
#      'volume_change_24h': 76.2266,
#      'percent_change_1h': 0.02473722,
#      'percent_change_24h': 0.05375853,
#      'percent_change_7d': 0.00712698,
#      'percent_change_30d': -0.01009936,
#      'percent_change_60d': -0.09387017,
#      'percent_change_90d': -0.14369823,
#      'market_cap': 5987681802.824876,
#      'market_cap_dominance': 0.1851,
#      'fully_diluted_market_cap': 5987681802.82,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 4943,
#    'name': 'Dai',
#    'symbol': 'DAI',
#    'slug': 'multi-collateral-dai',
#    'num_market_pairs': 3464,
#    'date_added': '2019-11-22T00:00:00.000Z',
#    'tags': ['defi',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'ethereum-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'near-protocol-ecosystem',
#     'arbitrum-ecosystem',
#     'harmony-ecosystem',
#     'moonriver-ecosystem',
#     'moonbeam-ecosystem',
#     'usd-stablecoin',
#     'everscale-ecosystem',
#     'optimism-ecosystem',
#     'osmosis-ecosystem',
#     'pulsechain-ecosystem',
#     'toncoin-ecosystem',
#     'gnosis-chain-ecosystem',
#     'klaytn-ecosystem',
#     'sora-ecosystem',
#     'boba-network-ecosystem',
#     'aurora-ecosystem',
#     'metis-andromeda-ecosystem',
#     'bitgert-ecosystem',
#     'energi-ecosystem',
#     'starknet-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 5365382702.664872,
#    'total_supply': 5365382702.664872,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#    'infinite_supply': True,
#    'cmc_rank': 26,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 1.0001900519083986,
#      'volume_24h': 219558825.9994412,
#      'volume_change_24h': -3.1734,
#      'percent_change_1h': -0.00420829,
#      'percent_change_24h': 0.02086384,
#      'percent_change_7d': 0.01825005,
#      'percent_change_30d': 0.00543179,
#      'percent_change_60d': 0.03115995,
#      'percent_change_90d': 0.04547844,
#      'market_cap': 5366402403.886803,
#      'market_cap_dominance': 0.1659,
#      'fully_diluted_market_cap': 5366402403.89,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 6536,
#    'name': 'MANTRA',
#    'symbol': 'OM',
#    'slug': 'mantra',
#    'num_market_pairs': 247,
#    'date_added': '2020-08-11T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'defi',
#     'dao',
#     'ethereum-ecosystem',
#     'kenetic-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'polygon-ecosystem',
#     'osmosis-ecosystem',
#     'real-world-assets',
#     'base-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 972294600.3799999,
#    'total_supply': 1807858101.1,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3593d125a4f7849a1b059e64f4517a86dd60c95d'},
#    'infinite_supply': True,
#    'cmc_rank': 27,
#    'self_reported_circulating_supply': 875834067.9,
#    'self_reported_market_cap': 4814861898.884376,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 5.49745902260806,
#      'volume_24h': 129648485.35239941,
#      'volume_change_24h': -51.9012,
#      'percent_change_1h': 0.34308111,
#      'percent_change_24h': -3.38527736,
#      'percent_change_7d': -11.87987979,
#      'percent_change_30d': 45.69006526,
#      'percent_change_60d': 36.85519476,
#      'percent_change_90d': 142.78948492,
#      'market_cap': 5345149723.492128,
#      'market_cap_dominance': 0.1654,
#      'fully_diluted_market_cap': 9938625829.49,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 24478,
#    'name': 'Pepe',
#    'symbol': 'PEPE',
#    'slug': 'pepe',
#    'num_market_pairs': 526,
#    'date_added': '2023-04-17T06:18:08.000Z',
#    'tags': ['memes', 'ethereum-ecosystem'],
#    'max_supply': 420690000000000,
#    'circulating_supply': 420689899653543.56,
#    'total_supply': 420689899653543.56,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6982508145454ce325ddbe47a25d4ec3d2311933'},
#    'infinite_supply': False,
#    'cmc_rank': 28,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 1.0337979915643167e-05,
#      'volume_24h': 618623357.56843,
#      'volume_change_24h': -24.4787,
#      'percent_change_1h': 0.83329145,
#      'percent_change_24h': 7.4678501,
#      'percent_change_7d': 8.01969906,
#      'percent_change_30d': -43.4726988,
#      'percent_change_60d': -55.3828291,
#      'percent_change_90d': -51.25714592,
#      'market_cap': 4349083733.332273,
#      'market_cap_dominance': 0.1345,
#      'fully_diluted_market_cap': 4349084770.71,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 21159,
#    'name': 'Ondo',
#    'symbol': 'ONDO',
#    'slug': 'ondo-finance',
#    'num_market_pairs': 255,
#    'date_added': '2024-01-18T12:06:25.000Z',
#    'tags': ['ethereum-ecosystem',
#     'real-world-assets',
#     'binance-alpha',
#     'cmc-crypto-yearbook-2024-2025',
#     'made-in-america'],
#    'max_supply': None,
#    'circulating_supply': 3159107529,
#    'total_supply': 10000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xfAbA6f8e4a5E8Ab82F62fe7C39859FA577269BE3'},
#    'infinite_supply': False,
#    'cmc_rank': 29,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 1.3493275744084499,
#      'volume_24h': 291183488.0901559,
#      'volume_change_24h': -13.9454,
#      'percent_change_1h': 0.92373214,
#      'percent_change_24h': 1.84235266,
#      'percent_change_7d': -5.94943949,
#      'percent_change_30d': 9.8788167,
#      'percent_change_60d': -33.2770435,
#      'percent_change_90d': 41.05611983,
#      'market_cap': 4262670899.4010415,
#      'market_cap_dominance': 0.1318,
#      'fully_diluted_market_cap': 13493275744.08,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 328,
#    'name': 'Monero',
#    'symbol': 'XMR',
#    'slug': 'monero',
#    'num_market_pairs': 309,
#    'date_added': '2014-05-21T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'medium-of-exchange',
#     'privacy',
#     'ringct',
# ...
#      'percent_change_7d': -0.28039218,
#      'percent_change_30d': -28.42279449,
#      'percent_change_60d': -38.65088787,
#      'percent_change_90d': -42.09665292,
#      'market_cap': 797120213.409743,
#      'market_cap_dominance': 0.0246,
#      'fully_diluted_market_cap': 797120213.41,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 32880,
#    'name': 'Kaia',
#    'symbol': 'KAIA',
#    'slug': 'kaia',
#    'num_market_pairs': 133,
#    'date_added': '2024-10-29T05:17:50.000Z',
#    'tags': ['platform', 'enterprise-solutions', 'layer-1', 'klaytn-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 5944624468.40501,
#    'total_supply': 5944624458.904881,
#    'platform': {'id': 32880,
#     'name': 'KAIA',
#     'symbol': 'KAIA',
#     'slug': 'kaia',
#     'token_address': '0x0000000000000000000000000000000000000000'},
#    'infinite_supply': True,
#    'cmc_rank': 89,
#    'self_reported_circulating_supply': 5944613064.602201,
#    'self_reported_market_cap': 795209297.3083122,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.13376973213672497,
#      'volume_24h': 24445566.19038304,
#      'volume_change_24h': -12.1771,
#      'percent_change_1h': 0.80341016,
#      'percent_change_24h': 2.41330225,
#      'percent_change_7d': -3.00654822,
#      'percent_change_30d': -39.2135673,
#      'percent_change_60d': -50.81910207,
#      'percent_change_90d': -4.43778326,
#      'market_cap': 795210822.7919593,
#      'market_cap_dominance': 0.0246,
#      'fully_diluted_market_cap': 795210821.52,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 28081,
#    'name': 'SPX6900',
#    'symbol': 'SPX',
#    'slug': 'spx6900',
#    'num_market_pairs': 329,
#    'date_added': '2023-08-17T10:00:00.000Z',
#    'tags': ['memes',
#     'ethereum-ecosystem',
#     'solana-ecosystem',
#     'base-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 930993090.07,
#    'total_supply': 930993090.07,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xe0f63a424a4439cbe457d80e4f4b51ad25b2c56c'},
#    'infinite_supply': False,
#    'cmc_rank': 90,
#    'self_reported_circulating_supply': 930993090.07,
#    'self_reported_market_cap': 773424503.3242048,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.83075214152884,
#      'volume_24h': 30797285.74645809,
#      'volume_change_24h': -13.1839,
#      'percent_change_1h': 4.44608881,
#      'percent_change_24h': 17.27441205,
#      'percent_change_7d': 24.41480201,
#      'percent_change_30d': -20.22146524,
#      'percent_change_60d': 8.61182724,
#      'percent_change_90d': 21.01921008,
#      'market_cap': 773424503.3242048,
#      'market_cap_dominance': 0.0239,
#      'fully_diluted_market_cap': 830752141.53,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 14101,
#    'name': 'Ronin',
#    'symbol': 'RON',
#    'slug': 'ronin',
#    'num_market_pairs': 81,
#    'date_added': '2021-11-08T17:57:40.000Z',
#    'tags': ['platform', 'gaming', 'staking', 'layer-1', 'ronin-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 619389698.9641546,
#    'total_supply': 1000000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 91,
#    'self_reported_circulating_supply': 619389698.9641546,
#    'self_reported_market_cap': 770341547.5213262,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 1.2437106216161136,
#      'volume_24h': 15754277.90079669,
#      'volume_change_24h': -52.6518,
#      'percent_change_1h': 0.33520628,
#      'percent_change_24h': 2.70109485,
#      'percent_change_7d': 15.87869978,
#      'percent_change_30d': -34.90010014,
#      'percent_change_60d': -40.87401529,
#      'percent_change_90d': -15.41351452,
#      'market_cap': 770341547.5213262,
#      'market_cap_dominance': 0.0238,
#      'fully_diluted_market_cap': 1243710621.62,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 28177,
#    'name': 'Pyth Network',
#    'symbol': 'PYTH',
#    'slug': 'pyth-network',
#    'num_market_pairs': 311,
#    'date_added': '2023-11-20T09:42:13.000Z',
#    'tags': ['oracles',
#     'solana-ecosystem',
#     'cross-chain',
#     'cmc-crypto-yearbook-2024-2025'],
#    'max_supply': 10000000000,
#    'circulating_supply': 3624988001.495366,
#    'total_supply': 9999988001.495365,
#    'platform': {'id': 5426,
#     'name': 'Solana',
#     'symbol': 'SOL',
#     'slug': 'solana',
#     'token_address': 'HZ1JovNiVvGrGNiiYvEozEVgZ58xaU3RKwX8eACQBCt3'},
#    'infinite_supply': False,
#    'cmc_rank': 92,
#    'self_reported_circulating_supply': 1500000000,
#    'self_reported_market_cap': 317423583.264432,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.211615722176288,
#      'volume_24h': 26419173.38916829,
#      'volume_change_24h': -30.0094,
#      'percent_change_1h': 0.85740378,
#      'percent_change_24h': 5.11467751,
#      'percent_change_7d': 11.14922742,
#      'percent_change_30d': -36.46198554,
#      'percent_change_60d': -55.19562967,
#      'percent_change_90d': -49.27669574,
#      'market_cap': 767104453.8168209,
#      'market_cap_dominance': 0.0237,
#      'fully_diluted_market_cap': 2116157221.76,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 18679,
#    'name': 'Onyxcoin',
#    'symbol': 'XCN',
#    'slug': 'onyxcoin',
#    'num_market_pairs': 128,
#    'date_added': '2022-03-09T16:10:43.000Z',
#    'tags': ['ethereum-ecosystem', 'base-ecosystem', 'made-in-america'],
#    'max_supply': 48402437326,
#    'circulating_supply': 32592684478,
#    'total_supply': 48402437326,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xA2cd3D43c775978A96BdBf12d733D5A1ED94fb18'},
#    'infinite_supply': False,
#    'cmc_rank': 93,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.023032896053565063,
#      'volume_24h': 134874331.93390533,
#      'volume_change_24h': -47.9527,
#      'percent_change_1h': 3.00041844,
#      'percent_change_24h': -4.27288687,
#      'percent_change_7d': -21.00772939,
#      'percent_change_30d': 721.02611269,
#      'percent_change_60d': 830.39775891,
#      'percent_change_90d': 1342.07587172,
#      'market_cap': 750703913.6884174,
#      'market_cap_dominance': 0.0232,
#      'fully_diluted_market_cap': 1114848307.67,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 35347,
#    'name': 'Official Melania Meme',
#    'symbol': 'MELANIA',
#    'slug': 'melania-meme',
#    'num_market_pairs': 246,
#    'date_added': '2025-01-19T23:21:51.000Z',
#    'tags': ['memes', 'solana-ecosystem', 'celebrity-memes', 'made-in-america'],
#    'max_supply': 1000000000,
#    'circulating_supply': 483313261.146396,
#    'total_supply': 999999358.062928,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 94,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 1.4914867581909177,
#      'volume_24h': 74237626.6107256,
#      'volume_change_24h': 30.2195,
#      'percent_change_1h': 3.17152074,
#      'percent_change_24h': 6.60344864,
#      'percent_change_7d': -1.61500149,
#      'percent_change_30d': -79.64688971,
#      'percent_change_60d': -79.64688971,
#      'percent_change_90d': -79.64688971,
#      'market_cap': 720855329.0579185,
#      'market_cap_dominance': 0.0223,
#      'fully_diluted_market_cap': 1491486758.19,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 28752,
#    'name': 'dogwifhat',
#    'symbol': 'WIF',
#    'slug': 'dogwifhat',
#    'num_market_pairs': 639,
#    'date_added': '2023-12-19T09:08:50.000Z',
#    'tags': ['memes',
#     'solana-ecosystem',
#     'doggone-doggerel',
#     'cmc-crypto-yearbook-2024-2025'],
#    'max_supply': None,
#    'circulating_supply': 998841366.81355,
#    'total_supply': 998841366.81355,
#    'platform': {'id': 5426,
#     'name': 'Solana',
#     'symbol': 'SOL',
#     'slug': 'solana',
#     'token_address': 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm'},
#    'infinite_supply': False,
#    'cmc_rank': 96,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.7213023931480135,
#      'volume_24h': 602020909.0892944,
#      'volume_change_24h': 67.696,
#      'percent_change_1h': 1.84234316,
#      'percent_change_24h': 24.52975419,
#      'percent_change_7d': -4.98166963,
#      'percent_change_30d': -56.10261026,
#      'percent_change_60d': -73.20752996,
#      'percent_change_90d': -80.22008387,
#      'market_cap': 720466668.2578464,
#      'market_cap_dominance': 0.0223,
#      'fully_diluted_market_cap': 720466668.26,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 7186,
#    'name': 'PancakeSwap',
#    'symbol': 'CAKE',
#    'slug': 'pancakeswap',
#    'num_market_pairs': 1631,
#    'date_added': '2020-09-25T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'decentralized-exchange-dex-token',
#     'defi',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'yield-farming',
#     'amm',
#     'binance-smart-chain',
#     'dex',
#     'governance',
#     'bnb-chain-ecosystem',
#     'aptos-ecosystem',
#     'zksync-era-ecosystem',
#     'base-ecosystem',
#     'linea-ecosystem',
#     'polygon-zkevm-ecosystem',
#     'opbnb-ecosystem'],
#    'max_supply': 450000000,
#    'circulating_supply': 291629966.5365029,
#    'total_supply': 379207513.7929145,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x152649eA73beAb28c5b49B26eb48f7EAD6d4c898'},
#    'infinite_supply': False,
#    'cmc_rank': 95,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': 0.40148056,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 2.4707469253159102,
#      'volume_24h': 572582596.4336717,
#      'volume_change_24h': -56.0393,
#      'percent_change_1h': -0.55441784,
#      'percent_change_24h': -12.78312652,
#      'percent_change_7d': 69.54814783,
#      'percent_change_30d': 2.45036387,
#      'percent_change_60d': -23.64799221,
#      'percent_change_90d': 29.69043395,
#      'market_cap': 720543843.1500463,
#      'market_cap_dominance': 0.0223,
#      'fully_diluted_market_cap': 1111836116.39,
#      'tvl': 1794716632.44042,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 5176,
#    'name': 'Tether Gold',
#    'symbol': 'XAUt',
#    'slug': 'tether-gold',
#    'num_market_pairs': 102,
#    'date_added': '2020-02-07T00:00:00.000Z',
#    'tags': ['ethereum-ecosystem', 'tokenized-gold'],
#    'max_supply': None,
#    'circulating_supply': 246524,
#    'total_supply': 246524,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x68749665FF8D2d112Fa859AA293F07A622782F38'},
#    'infinite_supply': False,
#    'cmc_rank': 97,
#    'self_reported_circulating_supply': 48450,
#    'self_reported_market_cap': 141348138.75679103,
#    'tvl_ratio': 0.99611726,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 2917.4022447222087,
#      'volume_24h': 3964503.7147585,
#      'volume_change_24h': -8.0574,
#      'percent_change_1h': 0.03740613,
#      'percent_change_24h': 0.06077254,
#      'percent_change_7d': 1.23477414,
#      'percent_change_30d': 10.06008327,
#      'percent_change_60d': 9.51266283,
#      'percent_change_90d': 13.73733786,
#      'market_cap': 719209670.9778978,
#      'market_cap_dominance': 0.0223,
#      'fully_diluted_market_cap': 719209670.98,
#      'tvl': 722013061.9741,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 6783,
#    'name': 'Axie Infinity',
#    'symbol': 'AXS',
#    'slug': 'axie-infinity',
#    'num_market_pairs': 506,
#    'date_added': '2020-08-31T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'gaming',
#     'ethereum-ecosystem',
#     'binance-launchpad',
#     'solana-ecosystem',
#     'metaverse',
#     'defiance-capital-portfolio',
#     'play-to-earn',
#     'animoca-brands-portfolio',
#     'harmony-ecosystem',
#     'alleged-sec-securities',
#     'ronin-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 158620557.2918257,
#    'total_supply': 270000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xbb0e17ef65f82ab018d8edd776e8dd940327b28b'},
#    'infinite_supply': False,
#    'cmc_rank': 98,
#    'self_reported_circulating_supply': 158620469.74406788,
#    'self_reported_market_cap': 715836642.1787075,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 4.512889435605007,
#      'volume_24h': 32491221.43528207,
#      'volume_change_24h': -30.3437,
#      'percent_change_1h': 0.68375118,
#      'percent_change_24h': 4.73631626,
#      'percent_change_7d': 8.22721755,
#      'percent_change_30d': -29.95634729,
#      'percent_change_60d': -39.07949815,
#      'percent_change_90d': -20.46435259,
#      'market_cap': 715837037.272059,
#      'market_cap_dominance': 0.0221,
#      'fully_diluted_market_cap': 1218480147.61,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 5665,
#    'name': 'Helium',
#    'symbol': 'HNT',
#    'slug': 'helium',
#    'num_market_pairs': 180,
#    'date_added': '2020-06-05T00:00:00.000Z',
#    'tags': ['mineable',
#     'enterprise-solutions',
#     'distributed-computing',
#     'iot',
#     'solana-ecosystem',
#     'usv-portfolio',
#     'multicoin-capital-portfolio',
#     'web3',
#     'depin',
#     'made-in-america'],
#    'max_supply': 223000000,
#    'circulating_supply': 177394590.46004692,
#    'total_supply': 177394590.46004692,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 99,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 3.987139634211121,
#      'volume_24h': 7697432.05415567,
#      'volume_change_24h': -13.15,
#      'percent_change_1h': 3.76134322,
#      'percent_change_24h': 6.84039528,
#      'percent_change_7d': 19.64072791,
#      'percent_change_30d': -17.65815699,
#      'percent_change_60d': -57.53033159,
#      'percent_change_90d': -31.08990941,
#      'market_cap': 707297002.5179031,
#      'market_cap_dominance': 0.0219,
#      'fully_diluted_market_cap': 889132138.43,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}},
#   {'id': 34466,
#    'name': 'Pudgy Penguins',
#    'symbol': 'PENGU',
#    'slug': 'pudgy-penguins',
#    'num_market_pairs': 287,
#    'date_added': '2024-12-17T14:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'memes',
#     'solana-ecosystem',
#     'animal-memes',
#     'ip-memes',
#     'made-in-america',
#     'binance-hodler-airdrops'],
#    'max_supply': None,
#    'circulating_supply': 62860396090.04,
#    'total_supply': 88888888888,
#    'platform': {'id': 5426,
#     'name': 'Solana',
#     'symbol': 'SOL',
#     'slug': 'solana',
#     'token_address': '2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv'},
#    'infinite_supply': False,
#    'cmc_rank': 101,
#    'self_reported_circulating_supply': 62860396090,
#    'self_reported_market_cap': 689125988.709722,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-14T15:13:00.000Z',
#    'quote': {'USD': {'price': 0.010962800611740816,
#      'volume_24h': 197343165.2767434,
#      'volume_change_24h': 5.8103,
#      'percent_change_1h': 1.92772466,
#      'percent_change_24h': 15.26568552,
#      'percent_change_7d': -3.49162392,
#      'percent_change_30d': -68.0040265,
#      'percent_change_60d': -80.89318397,
#      'percent_change_90d': -80.89318397,
#      'market_cap': 689125988.7101605,
#      'market_cap_dominance': 0.0213,
#      'fully_diluted_market_cap': 974471165.48,
#      'tvl': None,
#      'last_updated': '2025-02-14T15:13:00.000Z'}}}]}
